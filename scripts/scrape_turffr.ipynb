# %%
import pandas as pd

# %%
import requests

# %%
requests.get('https://www.turf-fr.com/getPageConcours').json()
# Out:
# [[{'course': {'concours_id': 7,
#     'course_id': 198214,
#     'course_numero': 1,
#     'date_journee': '2020-03-02',
#     'debut': '2020-03-01',
#     'fin': '2020-03-31',
#     'heure': '13:50:00',
#     'nom': 'Caen',
#     'nom_du_prix': 'PRIX DE SAINT-ETIENNE',
#     'partants': 16,
#     'reunion_numero': 1},
#    'date': '2020-03-02 13:30',
#    'heure': '13:30',
#    'prono': 0},
#   {'course': {'concours_id': 7,
#     'course_id': 198276,
#     'course_numero': 1,
#     'date_journee': '2020-03-03',
#     'debut': '2020-03-01',
#     'fin': '2020-03-31',
#     'heure': '13:50:00',
#     'nom': 'Chantilly',
#     'nom_du_prix': 'PRIX DU PAYS DE FRANCE',
#     'partants': 16,
#     'reunion_numero': 1},
#    'date': '2020-03-03 13:30',
#    'heure': '13:30',
#    'prono': 1}],
#  [{'points': 3376.3, 'pseudo': 'Deferrer'},
#   {'points': 1096.9, 'pseudo': 'Fh32pa59'},
#   {'points': 829.2, 'pseudo': 'Monseigneu'},
#   {'points': 715.2, 'pseudo': 'Attila'},
# ...

# %%
requests.get('https://www.turf-fr.com/getDetailCourse?id=192707').json()
# Out:
# [{'actus_id': 9265,
#   'arrivee': '5 - 8 - 6 - 2 - 4 - 13 - 1',
#   'conditions': "Pour 5 et 6 ans (F et E), ayant gagné au moins 50.000, mais pas 245.000. Sont seuls admis à participer à cette épreuve les chevaux n'ayant pas, dans les 12 mois précédant la course, été         classés, au trot attelé, 1er, 2ème ou 3ème",
# ...

# %%
requests.get('https://www.turf-fr.com/perfs?id=564938')

# %%
requests.get('https://www.turf-fr.com/')
# Out:
# <Response [200]>

# %%
"https://www.turf-fr.com/archives/tierce-quarte-quinte/2004/janvier"
requests.get("https://www.turf-fr.com/archives/courses-pmu/2004/janvier").text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="fr">\n    <head>\n        <!-- Google Tag Manager -->\n            <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n            new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n            })(window,document,\'script\',\'dataLayer\',\'GTM-PNGZ3CF\');</script>\n            <!-- End Google Tag Manager -->\n        <title id="balise_title">Archives PMU - Archives réunions PMU du mois de janvier de 2004 </title>\n        <meta name="description"  content="TURF FR vous propose les archives 🗄 de toutes les courses PMU de janvier 2004 !" >\n        <link rel="canonical"  href="https://www.turf-fr.com/archives/courses-pmu/2004/janvier" >\n        <meta http-equiv="Content-Type" content="text/html;" charset="utf-8">  
# ...

# %%
requests.get("https://www.turf-fr.com/fiche-cheval/564937").text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="fr">\n    <head>\n        <!-- Google Tag Manager -->\n            <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n            new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n            })(window,document,\'script\',\'dataLayer\',\'GTM-PNGZ3CF\');</script>\n            <!-- End Google Tag Manager -->\n        <title id="balise_title">FOUGERE : Fiche cheval - Palmarès et Actualités - TURF FR </title>\n        <meta name="description"  content="Fiche cheval FOUGERE ✅. Informations détaillées, statistiques générales et performances sur la carrière de FOUGERE" >\n        <link rel="canonical"  href="https://www.turf-fr.com/fiche-cheval/564937" >\n        <meta http-equiv="Content-Type" content="text/html;" cha
# ...
